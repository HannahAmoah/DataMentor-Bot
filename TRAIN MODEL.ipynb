# %%
import json
import pickle
import numpy as np
import random
import nltk
from nltk.stem import WordNetLemmatizer
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Load data
with open("intents.json", "r") as file:
    intents = json.load(file)

words = pickle.load(open("words.pkl", "rb"))
classes = pickle.load(open("classes.pkl", "rb"))

# Prepare training data
training = []
output_empty = [0] * len(classes)  # Placeholder for output labels

for intent in intents["intents"]:
    for pattern in intent["examples"]:  # Using 'examples' instead of 'patterns'
        word_list = nltk.word_tokenize(pattern)
        word_list = [lemmatizer.lemmatize(word.lower()) for word in word_list]

        bag = [1 if w in word_list else 0 for w in words]  # Create bag of words
        output_row = list(output_empty)
        output_row[classes.index(intent["intent"])] = 1  # Assign intent

        training.append([bag, output_row])

# Shuffle data and convert to NumPy arrays
random.shuffle(training)
train_x = np.array([entry[0] for entry in training])
train_y = np.array([entry[1] for entry in training])

# Define the neural network model
model = Sequential([
    Dense(128, input_shape=(len(train_x[0]),), activation="relu"),
    Dropout(0.5),
    Dense(64, activation="relu"),
    Dropout(0.5),
    Dense(len(train_y[0]), activation="softmax")
])

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.01), metrics=["accuracy"])

# Train the model
print("🟢 Training the chatbot model...")
history = model.fit(train_x, train_y, epochs=200, batch_size=8, verbose=1)

# Save the trained model
model.save("chatbot_model.keras")
print("✅ Model training complete! Saved as chatbot_model.keras")
# Out:
# 🟢 Training the chatbot model...
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1283 - loss: 2.2156
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2742 - loss: 2.0511
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4092 - loss: 1.8362
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3983 - loss: 1.7354
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6750 - loss: 1.3861
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6117 - loss: 1.3460
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7433 - loss: 1.1411
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6458 - loss: 0.9824
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7675 - loss: 0.7467
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8583 - loss: 0.5863
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8600 - loss: 0.4359
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7092 - loss: 0.6363
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.2076
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9658 - loss: 0.2112
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9067 - loss: 0.2078
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8717 - loss: 0.4173
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0614
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8467 - loss: 0.3132
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7667 - loss: 0.4778
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0270
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9442 - loss: 0.1086
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8758 - loss: 0.2570
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0735
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9408 - loss: 0.2889
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8933 - loss: 0.3375
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8475 - loss: 0.4481
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9525 - loss: 0.1673
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9442 - loss: 0.1384
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0241
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9650 - loss: 0.0992
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0388
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0278
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9317 - loss: 0.2127
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0307
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0207
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0458
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0781
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0143
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9317 - loss: 0.0837
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0458
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0227
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9408 - loss: 0.1045
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9783 - loss: 0.0394
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9867 - loss: 0.0572
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9067 - loss: 0.1512
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9783 - loss: 0.0257
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0291
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0171
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0235
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9658 - loss: 0.1101
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0327
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9658 - loss: 0.0382
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0316
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0214
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0691
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9783 - loss: 0.0383
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9783 - loss: 0.2272
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0250
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0250
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9658 - loss: 0.0474
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9867 - loss: 0.0847
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9658 - loss: 0.0955
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9783 - loss: 0.0307
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9658 - loss: 0.0323
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9658 - loss: 0.0387
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0169
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9783 - loss: 0.0340
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.7495e-04
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0357
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0164
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0251
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.0597
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0159
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0281
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0698
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0181
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0238
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0182
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 3.2802e-04
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.7555e-04
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8817 - loss: 0.1094
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0222
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0554
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.8745e-04
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 4.3431e-04
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 2.9579e-04
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.3802e-04
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9783 - loss: 0.0212
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9525 - loss: 0.1803
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9650 - loss: 0.0449
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9183 - loss: 0.1187
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9783 - loss: 0.0416
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9658 - loss: 0.0694
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9658 - loss: 0.0340
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9225 - loss: 0.1658
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0353
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8725 - loss: 0.3822
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9658 - loss: 0.2137
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9783 - loss: 0.0341
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9100 - loss: 0.3060
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9650 - loss: 0.1179
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9783 - loss: 0.0561
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9867 - loss: 0.1243
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9867 - loss: 0.0870
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9408 - loss: 0.2117
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8817 - loss: 0.2060
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9567 - loss: 0.2063
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9408 - loss: 0.0655
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0172
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9783 - loss: 0.0621
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9783 - loss: 0.1308
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9408 - loss: 0.3738
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9783 - loss: 0.4744
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0156
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0255
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9867 - loss: 0.0452
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9408 - loss: 0.1497
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8258 - loss: 1.1129
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9275 - loss: 0.1867
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9408 - loss: 0.2211
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9308 - loss: 0.2890
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0172
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9192 - loss: 0.2244
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9408 - loss: 0.0587
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9408 - loss: 0.0789
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9783 - loss: 0.0783
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 5.8281e-04
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.5599e-04
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.1454
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 3.5618e-04
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0261
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9408 - loss: 0.1729
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9658 - loss: 0.1718
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9525 - loss: 0.0944
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9658 - loss: 0.0688
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0339
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9867 - loss: 0.0417
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9442 - loss: 0.1189
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9867 - loss: 0.0769
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0331
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0174
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9650 - loss: 0.2608
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.9976e-05
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9867 - loss: 0.1857
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9658 - loss: 0.1330
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9783 - loss: 0.0333
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9867 - loss: 0.0367
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0234
# ✅ Model training complete! Saved as chatbot_model.keras

# %%
import json
import pickle
import nltk
import numpy as np
import random
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import load_model

# Load the model and necessary files
model = load_model("chatbot_model.keras")

with open("intents.json", "r") as file:
    intents = json.load(file)

# Load words and classes
with open("words.pkl", "rb") as file:
    words = pickle.load(file)

with open("classes.pkl", "rb") as file:
    classes = pickle.load(file)

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to preprocess and tokenize user input
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)  # Tokenize input
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]  # Lemmatize
    return sentence_words

# Function to create a bag-of-words representation
def bow(sentence, words):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)  # Ensure correct size
    for s in sentence_words:
        for i, word in enumerate(words):
            if word == s:
                bag[i] = 1
    return np.array(bag).reshape(1, -1)  # Ensure shape (1, len(words))

# Function to predict intent
def predict_class(sentence):
    bow_input = bow(sentence, words)

    # Check if input size matches expected input size
    if bow_input.shape[1] != len(words):
        print(f"Warning: Expected {len(words)} input features but got {bow_input.shape[1]}.")

    prediction = model.predict(bow_input)[0]  # Predict intent
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(prediction) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)

    return [{"intent": classes[r[0]], "probability": str(r[1])} for r in results]

# Function to get a response based on intent
def get_response(intents_list, intents_json):
    if not intents_list:
        return "I'm sorry, I didn't understand that. Can you rephrase?"

    tag = intents_list[0]["intent"]
    
    for intent in intents_json["intents"]:
        if intent["intent"] == tag:  # Ensure correct key name
            return random.choice(intent["responses"])

    return "I'm not sure how to respond to that."

# Main chatbot function
def chat():
    print("Chatbot is ready! Type 'quit' to exit.")
    while True:
        message = input("You: ")
        if message.lower() == "quit":
            print("Goodbye!")
            break
        
        intents_list = predict_class(message)
        response = get_response(intents_list, intents)
        
        print(f"Bot: {response}")

# Run the chatbot
chat()
# Out:
# Chatbot is ready! Type 'quit' to exit.
# You:  hi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Bot: Hi there! What can I do for you?
# You:  data science
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Bot: Data science is an interdisciplinary field that uses scientific methods, algorithms, and systems to extract insights and knowledge from structured and unstructured data. It combines elements of statistics, computer science, and domain knowledge to solve real-world problems.
# You:  careers
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Bot: Internship opportunities can be found on platforms like LinkedIn, Kaggle, GitHub, and company websites.
# You:  salary
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Bot: - **Entry-Level:** $70,000 - $100,000 per year
# You:  internship
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# Bot: - **AI Researcher**
# You:  data science
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Bot: Data science is an interdisciplinary field that uses scientific methods, algorithms, and systems to extract insights and knowledge from structured and unstructured data. It combines elements of statistics, computer science, and domain knowledge to solve real-world problems.
# You:  tools
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Bot: - **Database Management:** MySQL, PostgreSQL, MongoDB
# You:  careers and internship
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Bot: - **AI Researcher**
# You:  careers
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Bot: - **Data Analyst**
# You:  careers
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Bot: Career paths in data science include:
# You:  go
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Bot: Hello! How can I assist you today?
# You:  ckhkhjk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Bot: Hi there! What can I do for you?
# You:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Bot: Hello! How can I assist you today?
# You:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Bot: Hello! How can I assist you today?
# You:  uyu
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Bot: Hello! How can I assist you today?
# You:  what is data
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Bot: Data science is an interdisciplinary field that uses scientific methods, algorithms, and systems to extract insights and knowledge from structured and unstructured data. It combines elements of statistics, computer science, and domain knowledge to solve real-world problems.
# You:  careers
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Bot: - **Machine Learning Engineer**
# You:  internship
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Bot: Career paths in data science include:
# You:  go on
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Bot: Hello! How can I assist you today?

# %%
# Out:
# {
#     "intents": [
#         {
#             "intent": "Greeting",
#             "examples": [
#                 "Hello",
#                 "Hi",
#                 "Hey",
#                 "Good morning",
#                 "Good evening"
#             ],
#             "responses": [
#                 "Hello! How can I assist you today?",
#                 "Hi there! What can I do for you?"
#             ]
#         },
#         {
#             "intent": "Farewell",
#             "examples": [
#                 "Goodbye",
#                 "Bye",
#                 "See you later",
#                 "Take care"
#             ],
#             "responses": [
#                 "Goodbye! Have a great day!",
#                 "See you later! Feel free to ask anytime."
#             ]
#         },
#         {
#             "intent": "Introduction_to_Data_Science",
#             "examples": [
#                 "What is data science?",
#                 "Explain data science in simple terms.",
#                 "Why is data science important?"
#             ],
#             "responses": [
#                 "Data science is an interdisciplinary field that uses scientific methods, algorithms, and systems to extract insights and knowledge from structured and unstructured data. It combines elements of statistics, computer science, and domain knowledge to solve real-world problems."
#             ]
#         },
#         {
#             "intent": "Skills_Required_for_Data_Science",
#             "examples": [
#                 "What skills do I need to become a data scientist?",
#                 "What are the key skills in data science?",
#                 "How can I improve my data science skills?"
#             ],
#             "responses": [
#                 "To become a data scientist, you need a combination of technical and soft skills:",
#                 "- **Technical Skills:** Python, R, SQL, Machine Learning, Deep Learning, Data Visualization, Big Data Technologies (Hadoop, Spark), Cloud Computing (AWS, Azure, GCP)",
#                 "- **Soft Skills:** Problem-Solving, Communication, Critical Thinking, Business Acumen, Teamwork"
#             ]
#         },
#         {
#             "intent": "Tools_Used_in_Data_Science",
#             "examples": [
#                 "What are the most popular tools in data science?",
#                 "Which programming languages are used in data science?",
#                 "What software should I learn for data science?"
#             ],
#             "responses": [
#                 "Some commonly used tools in data science include:",
#                 "- **Programming Languages:** Python, R, SQL",
#                 "- **Machine Learning Libraries:** Scikit-Learn, TensorFlow, PyTorch",
#                 "- **Data Visualization:** Matplotlib, Seaborn, Power BI, Tableau",
#                 "- **Big Data & Cloud:** Hadoop, Apache Spark, AWS, Google Cloud Platform",
#                 "- **Database Management:** MySQL, PostgreSQL, MongoDB"
#             ]
#         },
#         {
#             "intent": "Roadmap_for_Data_Science",
#             "examples": [
#                 "How do I start my journey in data science?",
#                 "What is the roadmap to becoming a data scientist?",
#                 "Steps to learn data science from scratch?"
#             ],
#             "responses": [
#                 "A typical roadmap for learning data science includes:",
#                 "1. **Learn Programming:** Python or R",
#                 "2. **Understand Mathematics & Statistics:** Linear Algebra, Probability, Hypothesis Testing",
#                 "3. **Master Data Wrangling & Visualization:** Pandas, Matplotlib, Seaborn",
#                 "4. **Learn Machine Learning & Deep Learning:** Scikit-Learn, TensorFlow, PyTorch",
#                 "5. **Work with Databases & Big Data:** SQL, Hadoop, Spark",
#                 "6. **Gain Experience through Projects & Internships**",
#                 "7. **Build a Portfolio & Apply for Jobs**"
#             ]
#         },
#         {
#             "intent": "Career_Opportunities_in_Data_Science",
#             "examples": [
#                 "How do I get an internship in data science?",
#                 "What are the career opportunities in data science?",
#                 "Where can I find data science jobs?"
#             ],
#             "responses": [
#                 "Career paths in data science include:",
#                 "- **Data Analyst**",
#                 "- **Machine Learning Engineer**",
#                 "- **Data Engineer**",
#                 "- **AI Researcher**",
#                 "- **Business Intelligence Analyst**",
#                 "Internship opportunities can be found on platforms like LinkedIn, Kaggle, GitHub, and company websites."
#             ]
#         },
#         {
#             "intent": "Soft_Skills_for_Data_Scientists",
#             "examples": [
#                 "What soft skills are needed for data science?",
#                 "How important are communication skills in data science?",
#                 "What non-technical skills do data scientists need?"
#             ],
#             "responses": [
#                 "Soft skills essential for data science include:",
#                 "- **Problem-Solving:** Ability to analyze and break down complex problems",
#                 "- **Communication:** Explaining insights effectively to non-technical stakeholders",
#                 "- **Critical Thinking:** Evaluating and interpreting data accurately",
#                 "- **Collaboration:** Working in teams across multiple disciplines",
#                 "- **Time Management:** Handling multiple projects efficiently"
#             ]
#         },
#         {
#             "intent": "Salary_of_Data_Scientists",
#             "examples": [
#                 "What is the average salary of a data scientist?",
#                 "How much do data scientists earn?",
#                 "What is the salary range for entry-level data scientists?"
#             ],
#             "responses": [
#                 "Salaries for data scientists vary based on location, experience, and industry:",
#                 "- **Entry-Level:** $70,000 - $100,000 per year",
#                 "- **Mid-Level:** $100,000 - $150,000 per year",
#                 "- **Senior-Level:** $150,000+ per year",
#                 "Tech hubs like the USA, UK, and Germany offer higher salaries compared to other regions."
#             ]
#         }
#     ]
# }
